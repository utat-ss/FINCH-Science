# %%
# %load_ext autoreload
# %autoreload 2

# Define autroreload so that it doesn't cause pain in the ass when we change the functions and run this notebook

# %%
# Imports

import pandas as pd
import numpy as np

# Define the relative paths, append it to the system path
import sys
from pathlib import Path

project_root = Path.cwd().resolve().parents[2] # Gets the folder: Unconventional_Unmixing_Methods\NeuralNet
sys.path.append(str(project_root))

# Import the models and shi
from defs.helper_functions.training_functions import *
from defs.helper_functions.loss_functions import *
from defs.helper_functions.plot_functions import *

# Time, to precisely, time
import time

# %%
# Set device

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")  # Force CPU for testing purposes
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Basics of the dataset

master_root = Path.cwd().resolve().parents[7] # Gets the folder: UTAT on Ege's computer, which has Github and Data, use this to import the data
sys.path.append(str(master_root))

data_handle = rf'{master_root}\Data\General_Data\simpler_data_rwc.csv'

cfg_dataset = {
    'abundance_idx_range': [0,2], # -1 from original since we have spectra col
    'value_idx_range': [55,135], # -2 from original since we have use and spectra col
    'identity_idx_range': [3,3] # -1 from original since we have spectra col, use RWC as identity for now, since we do not have pure idx col
}

df = pd.read_csv(data_handle)
df = df.iloc[:-3] # Drop last 3 rows since we need divisible fold number to the rows
df = df.drop(columns=['Spectra', 'use']) # Drop these two since we will convert to a tensor
data_np = df.values.astype('float32')
data_tensor = torch.from_numpy(data_np)

# %%
# Cfgs for the network, optimizer, training

# Network cfg:

cfg_model = {
    'model_type': 'MLP',
    'input_dim': 81,
    'output_dim': 3,
    'hidden_layers': [64,64,64,32,16],
    'activation_list': ['Sigmoid', 'Sigmoid', 'Sigmoid', 'Sigmoid', 'Sigmoid', 'Sigmoid']
}

cfg_optim = {
    'algo': 'adamw',
    'lr': 1e-4
}

cfg_train = {
    'fold': 10,
    'batch_size': 1,
    'loss': 'total'
}

# %%
cfg_loss = {
    'lambdas_ab': torch.tensor([5, 15, 15]),
    'lambda_sum': 0.1,
    'lambda_bounds': 0.08
}

loss = ClassWisePhysical(cfg_loss= cfg_loss, device= device)

# %%
folds_dict = train_k_fold(cfg_train= cfg_train, cfg_dataset= cfg_dataset, cfg_model= cfg_model, cfg_optim= cfg_optim, dataset= data_tensor, device= device, loss= loss)
# Out:
# Training 1 at fold 0 finished
# Training 2 at fold 0 finished
# Training 3 at fold 0 finished
# Training 4 at fold 0 finished
# Training 5 at fold 0 finished
# Training 6 at fold 0 finished
# Training 7 at fold 0 finished
# Training 8 at fold 0 finished
# Training 9 at fold 0 finished
# Training 10 at fold 0 finished
# Training 11 at fold 0 finished
# Training 12 at fold 0 finished
# Training 13 at fold 0 finished
# Training 14 at fold 0 finished
# Training 15 at fold 0 finished
# Training 16 at fold 0 finished
# Training 17 at fold 0 finished
# Training 18 at fold 0 finished
# Training 19 at fold 0 finished
# Training 20 at fold 0 finished
# Training 21 at fold 0 finished
# Training 22 at fold 0 finished
# Training 23 at fold 0 finished
# Training 24 at fold 0 finished
# Training 25 at fold 0 finished
# Training 26 at fold 0 finished
# Training 27 at fold 0 finished
# Training 28 at fold 0 finished
# Training 29 at fold 0 finished
# Training 30 at fold 0 finished
# Training 31 at fold 0 finished
# Training 32 at fold 0 finished
# Training 33 at fold 0 finished
# Training 34 at fold 0 finished
# Training 35 at fold 0 finished
# Training 36 at fold 0 finished
# Training 37 at fold 0 finished
# Training 38 at fold 0 finished
# Training 39 at fold 0 finished
# Training 40 at fold 0 finished
# Training 41 at fold 0 finished
# Training 42 at fold 0 finished
# Training 43 at fold 0 finished
# Training 44 at fold 0 finished
# Training 45 at fold 0 finished
# Training 46 at fold 0 finished
# Training 47 at fold 0 finished
# Training 48 at fold 0 finished
# Training 49 at fold 0 finished
# Training 50 at fold 0 finished
# Training 51 at fold 0 finished
# Training 52 at fold 0 finished
# Training 53 at fold 0 finished
# Training 54 at fold 0 finished
# Training 55 at fold 0 finished
# Training 56 at fold 0 finished
# Training 57 at fold 0 finished
# Training 58 at fold 0 finished
# Training 59 at fold 0 finished
# Training 60 at fold 0 finished
# Training 61 at fold 0 finished
# Training 62 at fold 0 finished
# Training 63 at fold 0 finished
# Training 64 at fold 0 finished
# Training 65 at fold 0 finished
# Training 66 at fold 0 finished
# Training 67 at fold 0 finished
# Training 68 at fold 0 finished
# Training 69 at fold 0 finished
# Training 70 at fold 0 finished
# Training 71 at fold 0 finished
# Training 72 at fold 0 finished
# Training 73 at fold 0 finished
# Training 74 at fold 0 finished
# Training 75 at fold 0 finished
# Training 76 at fold 0 finished
# Training 77 at fold 0 finished
# Training 78 at fold 0 finished
# Training 79 at fold 0 finished
# Training 80 at fold 0 finished
# Training 81 at fold 0 finished
# Training 82 at fold 0 finished
# Training 83 at fold 0 finished
# Training 84 at fold 0 finished
# Training 85 at fold 0 finished
# Training 86 at fold 0 finished
# Training 87 at fold 0 finished
# Training 88 at fold 0 finished
# Training 89 at fold 0 finished
# Training 90 at fold 0 finished
# Training 91 at fold 0 finished
# Training 92 at fold 0 finished
# Training 93 at fold 0 finished
# Training 94 at fold 0 finished
# Training 95 at fold 0 finished
# Training 96 at fold 0 finished
# Training 97 at fold 0 finished
# Training 98 at fold 0 finished
# Training 99 at fold 0 finished
# Training 100 at fold 0 finished
# Training 101 at fold 0 finished
# Training 102 at fold 0 finished
# Training 103 at fold 0 finished
# Training 104 at fold 0 finished
# Training 105 at fold 0 finished
# Training 106 at fold 0 finished
# Training 107 at fold 0 finished
# Training 108 at fold 0 finished
# Training 109 at fold 0 finished
# Training 110 at fold 0 finished
# Training 111 at fold 0 finished
# Training 112 at fold 0 finished
# Training 113 at fold 0 finished
# Training 114 at fold 0 finished
# Training 115 at fold 0 finished
# Training 116 at fold 0 finished
# Training 117 at fold 0 finished
# Training 118 at fold 0 finished
# Training 119 at fold 0 finished
# Training 120 at fold 0 finished
# Training 121 at fold 0 finished
# Training 122 at fold 0 finished
# Training 123 at fold 0 finished
# Training 124 at fold 0 finished
# Training 125 at fold 0 finished
# Training 126 at fold 0 finished
# Training 127 at fold 0 finished
# Training 128 at fold 0 finished
# Training 129 at fold 0 finished
# Training 130 at fold 0 finished
# Training 131 at fold 0 finished
# Training 132 at fold 0 finished
# Training 133 at fold 0 finished
# Training 134 at fold 0 finished
# Training 135 at fold 0 finished
# Training 136 at fold 0 finished
# Training 137 at fold 0 finished
# Training 138 at fold 0 finished
# Training 139 at fold 0 finished
# Training 140 at fold 0 finished
# Training 141 at fold 0 finished
# Training 142 at fold 0 finished
# Training 143 at fold 0 finished
# Training 144 at fold 0 finished
# Training 145 at fold 0 finished
# Training 146 at fold 0 finished
# Training 147 at fold 0 finished
# Training 148 at fold 0 finished
# Training 149 at fold 0 finished
# Training 150 at fold 0 finished
# Training 151 at fold 0 finished
# Training 152 at fold 0 finished
# Training 153 at fold 0 finished
# Training 154 at fold 0 finished
# Training 155 at fold 0 finished
# Training 156 at fold 0 finished
# Training 157 at fold 0 finished
# Training 158 at fold 0 finished
# Training 159 at fold 0 finished
# Training 160 at fold 0 finished
# Training 161 at fold 0 finished
# Training 162 at fold 0 finished
# Training 163 at fold 0 finished
# Training 164 at fold 0 finished
# Training 165 at fold 0 finished
# Training 166 at fold 0 finished
# Training 167 at fold 0 finished
# Training 168 at fold 0 finished
# Training 169 at fold 0 finished
# Training 170 at fold 0 finished
# Training 171 at fold 0 finished
# Training 172 at fold 0 finished
# Training 173 at fold 0 finished
# Training 174 at fold 0 finished
# Training 175 at fold 0 finished
# Training 176 at fold 0 finished
# Training 177 at fold 0 finished
# Training 178 at fold 0 finished
# Training 179 at fold 0 finished
# Training 180 at fold 0 finished
# Training 181 at fold 0 finished
# Training 182 at fold 0 finished
# Training 183 at fold 0 finished
# Training 184 at fold 0 finished
# Training 185 at fold 0 finished
# Training 186 at fold 0 finished
# Training 187 at fold 0 finished
# Training 188 at fold 0 finished
# Training 189 at fold 0 finished
# Training 190 at fold 0 finished
# Training 191 at fold 0 finished
# Training 192 at fold 0 finished
# Training 193 at fold 0 finished
# Training 194 at fold 0 finished
# Training 195 at fold 0 finished
# Training 196 at fold 0 finished
# Training 197 at fold 0 finished
# Training 198 at fold 0 finished
# Training 199 at fold 0 finished
# Training 200 at fold 0 finished
# Training 201 at fold 0 finished
# Training 202 at fold 0 finished
# Training 203 at fold 0 finished
# Training 204 at fold 0 finished
# Training 205 at fold 0 finished
# Training 206 at fold 0 finished
# Training 207 at fold 0 finished
# Training 208 at fold 0 finished
# Training 209 at fold 0 finished
# Training 210 at fold 0 finished
# Training 211 at fold 0 finished
# Training 212 at fold 0 finished
# Training 213 at fold 0 finished
# Training 214 at fold 0 finished
# Training 215 at fold 0 finished
# Training 216 at fold 0 finished
# Training 217 at fold 0 finished
# Training 218 at fold 0 finished
# Training 219 at fold 0 finished
# Training 220 at fold 0 finished
# Training 221 at fold 0 finished
# Training 222 at fold 0 finished
# Training 223 at fold 0 finished
# Training 224 at fold 0 finished
# Training 225 at fold 0 finished
# Training 226 at fold 0 finished
# Training 227 at fold 0 finished
# Training 228 at fold 0 finished
# Training 229 at fold 0 finished
# Training 230 at fold 0 finished
# Training 231 at fold 0 finished
# Training 232 at fold 0 finished
# Training 233 at fold 0 finished
# Training 234 at fold 0 finished
# Training 235 at fold 0 finished
# Training 236 at fold 0 finished
# Training 237 at fold 0 finished
# Training 238 at fold 0 finished
# Training 239 at fold 0 finished
# Training 240 at fold 0 finished
# Training 241 at fold 0 finished
# Training 242 at fold 0 finished
# Training 243 at fold 0 finished
# Training 244 at fold 0 finished
# Training 245 at fold 0 finished
# Training 246 at fold 0 finished
# Training 247 at fold 0 finished
# Training 248 at fold 0 finished
# Training 249 at fold 0 finished
# Training 250 at fold 0 finished
# Training 251 at fold 0 finished
# Training 252 at fold 0 finished
# Training 253 at fold 0 finished
# Training 254 at fold 0 finished
# Training 255 at fold 0 finished
# Training 256 at fold 0 finished
# Training 257 at fold 0 finished
# Training 258 at fold 0 finished
# Training 259 at fold 0 finished
# Training 260 at fold 0 finished
# Training 261 at fold 0 finished
# Training 262 at fold 0 finished
# Training 263 at fold 0 finished
# Training 264 at fold 0 finished
# Training 265 at fold 0 finished
# Training 266 at fold 0 finished
# Training 267 at fold 0 finished
# Training 268 at fold 0 finished
# Training 269 at fold 0 finished
# Training 270 at fold 0 finished
# Training 271 at fold 0 finished
# Training 272 at fold 0 finished
# Training 273 at fold 0 finished
# Training 274 at fold 0 finished
# Training 275 at fold 0 finished
# Training 276 at fold 0 finished
# Training 277 at fold 0 finished
# Training 278 at fold 0 finished
# Training 279 at fold 0 finished
# Training 280 at fold 0 finished
# Training 281 at fold 0 finished
# Training 282 at fold 0 finished
# Training 283 at fold 0 finished
# Training 284 at fold 0 finished
# Training 285 at fold 0 finished
# Training 286 at fold 0 finished
# Training 287 at fold 0 finished
# Training 288 at fold 0 finished
# Training 289 at fold 0 finished
# Training 290 at fold 0 finished
# Training 291 at fold 0 finished
# Training 292 at fold 0 finished
# Training 293 at fold 0 finished
# Training 294 at fold 0 finished
# Training 295 at fold 0 finished
# Training 296 at fold 0 finished
# Training 297 at fold 0 finished
# Training 298 at fold 0 finished
# Training 299 at fold 0 finished
# Training 300 at fold 0 finished
# Training 301 at fold 0 finished
# Training 302 at fold 0 finished
# Training 303 at fold 0 finished
# Training 304 at fold 0 finished
# Training 305 at fold 0 finished
# Training 306 at fold 0 finished
# Training 307 at fold 0 finished
# Training 308 at fold 0 finished
# Training 309 at fold 0 finished
# Training 310 at fold 0 finished
# Training 311 at fold 0 finished
# Training 312 at fold 0 finished
# Training 313 at fold 0 finished
# Training 314 at fold 0 finished
# Training 315 at fold 0 finished
# Training 316 at fold 0 finished
# Training 317 at fold 0 finished
# Training 318 at fold 0 finished
# Training 319 at fold 0 finished
# Training 320 at fold 0 finished
# Training 321 at fold 0 finished
# Training 322 at fold 0 finished
# Training 323 at fold 0 finished
# Training 324 at fold 0 finished
# Training 325 at fold 0 finished
# Training 326 at fold 0 finished
# Training 327 at fold 0 finished
# Training 328 at fold 0 finished
# Training 329 at fold 0 finished
# Training 330 at fold 0 finished
# Training 331 at fold 0 finished
# Training 332 at fold 0 finished
# Training 333 at fold 0 finished
# Training 334 at fold 0 finished
# Training 335 at fold 0 finished
# Training 336 at fold 0 finished
# Training 337 at fold 0 finished
# Training 338 at fold 0 finished
# Training 339 at fold 0 finished
# Training 340 at fold 0 finished
# Training 341 at fold 0 finished
# Training 342 at fold 0 finished
# Training 343 at fold 0 finished
# Training 344 at fold 0 finished
# Training 345 at fold 0 finished
# Training 346 at fold 0 finished
# Training 347 at fold 0 finished
# Training 348 at fold 0 finished
# Training 349 at fold 0 finished
# Training 350 at fold 0 finished
# Training 351 at fold 0 finished
# Training 352 at fold 0 finished
# Training 353 at fold 0 finished
# Training 354 at fold 0 finished
# Training 355 at fold 0 finished
# Training 356 at fold 0 finished
# Training 357 at fold 0 finished
# Training 358 at fold 0 finished
# Training 359 at fold 0 finished
# Training 360 at fold 0 finished
# Training 361 at fold 0 finished
# Training 362 at fold 0 finished
# Training 363 at fold 0 finished
# Training 364 at fold 0 finished
# Training 365 at fold 0 finished
# Training 366 at fold 0 finished
# Training 367 at fold 0 finished
# Training 368 at fold 0 finished
# Training 369 at fold 0 finished
# Training 370 at fold 0 finished
# Training 371 at fold 0 finished
# Training 372 at fold 0 finished
# Training 373 at fold 0 finished
# Training 374 at fold 0 finished
# Training 375 at fold 0 finished
# Training 376 at fold 0 finished
# Training 377 at fold 0 finished
# Training 378 at fold 0 finished
# Training 379 at fold 0 finished
# Training 380 at fold 0 finished
# Training 381 at fold 0 finished
# Training 382 at fold 0 finished
# Training 383 at fold 0 finished
# Training 384 at fold 0 finished
# Training 385 at fold 0 finished
# Training 386 at fold 0 finished
# Training 387 at fold 0 finished
# Training 388 at fold 0 finished
# Training 389 at fold 0 finished
# Training 390 at fold 0 finished
# Training 391 at fold 0 finished
# Training 392 at fold 0 finished
# Training 393 at fold 0 finished
# Training 394 at fold 0 finished
# Training 395 at fold 0 finished
# Training 396 at fold 0 finished
# Training 397 at fold 0 finished
# Training 398 at fold 0 finished
# Training 399 at fold 0 finished
# Training 400 at fold 0 finished
# Training 401 at fold 0 finished
# Training 402 at fold 0 finished
# Training 403 at fold 0 finished
# Training 404 at fold 0 finished
# Training 405 at fold 0 finished
# Training 406 at fold 0 finished
# Training 407 at fold 0 finished
# Training 408 at fold 0 finished
# Training 409 at fold 0 finished
# Training 410 at fold 0 finished
# Training 411 at fold 0 finished
# Training 412 at fold 0 finished
# Training 413 at fold 0 finished
# Training 414 at fold 0 finished
# Training 415 at fold 0 finished
# Training 416 at fold 0 finished
# Training 417 at fold 0 finished
# Training 418 at fold 0 finished
# Training 419 at fold 0 finished
# Training 420 at fold 0 finished
# Training 421 at fold 0 finished
# Training 422 at fold 0 finished
# Training 423 at fold 0 finished
# Training 424 at fold 0 finished
# Training 425 at fold 0 finished
# Training 426 at fold 0 finished
# Training 427 at fold 0 finished
# Training 428 at fold 0 finished
# Training 429 at fold 0 finished
# Training 430 at fold 0 finished
# Training 431 at fold 0 finished
# Training 432 at fold 0 finished
# Training 433 at fold 0 finished
# Training 434 at fold 0 finished
# Training 435 at fold 0 finished
# Training 436 at fold 0 finished
# Training 437 at fold 0 finished
# Training 438 at fold 0 finished
# Training 439 at fold 0 finished
# Training 440 at fold 0 finished
# Training 441 at fold 0 finished
# Training 442 at fold 0 finished
# Training 443 at fold 0 finished
# Training 444 at fold 0 finished
# Training 445 at fold 0 finished
# Training 446 at fold 0 finished
# Training 447 at fold 0 finished
# Training 448 at fold 0 finished
# Training 449 at fold 0 finished
# Training 450 at fold 0 finished
# Training 451 at fold 0 finished
# Training 452 at fold 0 finished
# Training 453 at fold 0 finished
# Training 454 at fold 0 finished
# Training 455 at fold 0 finished
# Training 456 at fold 0 finished
# Training 457 at fold 0 finished
# Training 458 at fold 0 finished
# Training 459 at fold 0 finished
# Training 460 at fold 0 finished
# Training 461 at fold 0 finished
# Training 462 at fold 0 finished
# Training 463 at fold 0 finished
# Training 464 at fold 0 finished
# Training 465 at fold 0 finished
# Training 466 at fold 0 finished
# Training 467 at fold 0 finished
# Training 468 at fold 0 finished
# Training 469 at fold 0 finished
# Training 470 at fold 0 finished
# Training 471 at fold 0 finished
# Training 472 at fold 0 finished
# Training 473 at fold 0 finished
# Training 474 at fold 0 finished
# Training 475 at fold 0 finished
# Training 476 at fold 0 finished
# Training 477 at fold 0 finished
# Training 478 at fold 0 finished
# Training 479 at fold 0 finished
# Training 480 at fold 0 finished
# Training 481 at fold 0 finished
# Training 482 at fold 0 finished
# Training 483 at fold 0 finished
# Training 484 at fold 0 finished
# Training 485 at fold 0 finished
# Training 486 at fold 0 finished
# Training 487 at fold 0 finished
# Training 488 at fold 0 finished
# Training 489 at fold 0 finished
# Training 490 at fold 0 finished
# Training 491 at fold 0 finished
# Training 492 at fold 0 finished
# Training 493 at fold 0 finished
# Training 494 at fold 0 finished
# Training 495 at fold 0 finished
# Training 496 at fold 0 finished
# Training 497 at fold 0 finished
# Training 498 at fold 0 finished
# Training 499 at fold 0 finished
# Training 500 at fold 0 finished
# Training 501 at fold 0 finished
# Training 502 at fold 0 finished
# Training 503 at fold 0 finished
# Training 504 at fold 0 finished
# Training 505 at fold 0 finished
# Training 506 at fold 0 finished
# Training 507 at fold 0 finished
# Training 508 at fold 0 finished
# Training 509 at fold 0 finished
# Training 510 at fold 0 finished
# Training 511 at fold 0 finished
# Training 512 at fold 0 finished
# Training 513 at fold 0 finished
# Training 514 at fold 0 finished
# Training 515 at fold 0 finished
# Training 516 at fold 0 finished
# Training 517 at fold 0 finished
# Training 518 at fold 0 finished
# Training 519 at fold 0 finished
# Training 520 at fold 0 finished
# Training 521 at fold 0 finished
# Training 522 at fold 0 finished
# Training 523 at fold 0 finished
# Training 524 at fold 0 finished
# Training 525 at fold 0 finished
# Training 526 at fold 0 finished
# Training 527 at fold 0 finished
# Training 528 at fold 0 finished
# Training 529 at fold 0 finished
# Training 530 at fold 0 finished
# Training 531 at fold 0 finished
# Training 532 at fold 0 finished
# Training 533 at fold 0 finished
# Training 534 at fold 0 finished
# Training 535 at fold 0 finished
# Training 536 at fold 0 finished
# Training 537 at fold 0 finished
# Training 538 at fold 0 finished
# Training 539 at fold 0 finished
# Training 540 at fold 0 finished
# Training 541 at fold 0 finished
# Training 542 at fold 0 finished
# Training 543 at fold 0 finished
# Training 544 at fold 0 finished
# Training 545 at fold 0 finished
# Training 546 at fold 0 finished
# Training 547 at fold 0 finished
# Training 548 at fold 0 finished
# Training 549 at fold 0 finished
# Training 550 at fold 0 finished
# Training 551 at fold 0 finished
# Training 552 at fold 0 finished
# Training 553 at fold 0 finished
# Training 554 at fold 0 finished
# Training 555 at fold 0 finished
# Training 556 at fold 0 finished
# Training 557 at fold 0 finished
# Training 558 at fold 0 finished
# Training 559 at fold 0 finished
# Training 560 at fold 0 finished
# Training 561 at fold 0 finished
# Training 562 at fold 0 finished
# Training 563 at fold 0 finished
# Training 564 at fold 0 finished
# Training 565 at fold 0 finished
# Training 566 at fold 0 finished
# Training 567 at fold 0 finished
# Training 568 at fold 0 finished
# Training 569 at fold 0 finished
# Training 570 at fold 0 finished
# Training 571 at fold 0 finished
# Training 572 at fold 0 finished
# Training 573 at fold 0 finished
# Training 574 at fold 0 finished
# Training 575 at fold 0 finished
# Training 576 at fold 0 finished
# Training 577 at fold 0 finished
# Training 578 at fold 0 finished
# Training 579 at fold 0 finished
# Training 580 at fold 0 finished
# Training 581 at fold 0 finished
# Training 582 at fold 0 finished
# Training 583 at fold 0 finished
# Training 584 at fold 0 finished
# Training 585 at fold 0 finished
# Training 586 at fold 0 finished
# Training 587 at fold 0 finished
# Training 588 at fold 0 finished
# Training 589 at fold 0 finished
# Training 590 at fold 0 finished
# Training 591 at fold 0 finished
# Training 592 at fold 0 finished
# Training 593 at fold 0 finished
# Training 594 at fold 0 finished
# Training 595 at fold 0 finished
# Training 596 at fold 0 finished
# Training 597 at fold 0 finished
# Training 598 at fold 0 finished
# Training 599 at fold 0 finished
# Training 600 at fold 0 finished
# Training 601 at fold 0 finished
# Training 602 at fold 0 finished
# Training 603 at fold 0 finished
# Training 604 at fold 0 finished
# Training 605 at fold 0 finished
# Training 606 at fold 0 finished
# Training 607 at fold 0 finished
# Training 608 at fold 0 finished
# Training 609 at fold 0 finished
# Training 610 at fold 0 finished
# Training 611 at fold 0 finished
# Training 612 at fold 0 finished
# Training 613 at fold 0 finished
# Training 614 at fold 0 finished
# Training 615 at fold 0 finished
# Training 616 at fold 0 finished
# Training 617 at fold 0 finished
# Training 618 at fold 0 finished
# Training 619 at fold 0 finished
# Training 620 at fold 0 finished
# Training 621 at fold 0 finished
# Training 622 at fold 0 finished
# Training 623 at fold 0 finished
# Training 624 at fold 0 finished
# Training 625 at fold 0 finished
# Training 626 at fold 0 finished
# Training 627 at fold 0 finished
# Training 628 at fold 0 finished
# Training 629 at fold 0 finished
# Training 630 at fold 0 finished
# Training 631 at fold 0 finished
# Training 632 at fold 0 finished
# Training 633 at fold 0 finished
# Training 634 at fold 0 finished
# Training 635 at fold 0 finished
# Training 636 at fold 0 finished
# Training 637 at fold 0 finished
# Training 638 at fold 0 finished
# Training 639 at fold 0 finished
# Training 640 at fold 0 finished
# Training 641 at fold 0 finished
# Training 642 at fold 0 finished
# Training 643 at fold 0 finished
# Training 644 at fold 0 finished
# Training 645 at fold 0 finished
# Training 646 at fold 0 finished
# Training 647 at fold 0 finished
# Training 648 at fold 0 finished
# Training 649 at fold 0 finished
# Training 650 at fold 0 finished
# Training 651 at fold 0 finished
# Training 652 at fold 0 finished
# Training 653 at fold 0 finished
# Training 654 at fold 0 finished
# Training 655 at fold 0 finished
# Training 656 at fold 0 finished
# Training 657 at fold 0 finished
# Training 658 at fold 0 finished
# Training 659 at fold 0 finished
# Training 660 at fold 0 finished
# Training 661 at fold 0 finished
# Training 662 at fold 0 finished
# Training 663 at fold 0 finished
# Training 664 at fold 0 finished
# Training 665 at fold 0 finished
# Training 666 at fold 0 finished
# Training 667 at fold 0 finished
# Training 668 at fold 0 finished
# Training 669 at fold 0 finished
# Training 670 at fold 0 finished
# Training 671 at fold 0 finished
# Training 672 at fold 0 finished
# Training 673 at fold 0 finished
# Training 674 at fold 0 finished
# Training 675 at fold 0 finished
# Training 676 at fold 0 finished
# Training 677 at fold 0 finished
# Training 678 at fold 0 finished
# Training 679 at fold 0 finished
# Training 680 at fold 0 finished
# Training 681 at fold 0 finished
# Training 682 at fold 0 finished
# Training 683 at fold 0 finished
# Training 684 at fold 0 finished
# Training 685 at fold 0 finished
# Training 686 at fold 0 finished
# Training 687 at fold 0 finished
# Training 688 at fold 0 finished
# Training 689 at fold 0 finished
# Training 690 at fold 0 finished
# Training 691 at fold 0 finished
# Training 692 at fold 0 finished
# Training 693 at fold 0 finished
# Training 694 at fold 0 finished
# Training 695 at fold 0 finished
# Training 696 at fold 0 finished
# Training 697 at fold 0 finished
# Training 698 at fold 0 finished
# Training 699 at fold 0 finished
# Training 700 at fold 0 finished
# Training 701 at fold 0 finished
# Training 702 at fold 0 finished
# Training 703 at fold 0 finished
# Training 704 at fold 0 finished
# Training 705 at fold 0 finished
# Training 706 at fold 0 finished
# Training 707 at fold 0 finished
# Training 708 at fold 0 finished
# Training 709 at fold 0 finished
# Training 710 at fold 0 finished
# Training 711 at fold 0 finished
# Training 712 at fold 0 finished
# Training 713 at fold 0 finished
# Training 714 at fold 0 finished
# Training 715 at fold 0 finished
# Training 716 at fold 0 finished
# Training 717 at fold 0 finished
# Training 718 at fold 0 finished
# Training 719 at fold 0 finished
# Training 720 at fold 0 finished
# Training 721 at fold 0 finished
# Training 722 at fold 0 finished
# Training 723 at fold 0 finished
# Training 724 at fold 0 finished
# Training 725 at fold 0 finished
# Training 726 at fold 0 finished
# Training 727 at fold 0 finished
# Training 728 at fold 0 finished
# Training 729 at fold 0 finished
# Training 730 at fold 0 finished
# Training 731 at fold 0 finished
# Training 732 at fold 0 finished
# Training 733 at fold 0 finished
# Training 734 at fold 0 finished
# Training 735 at fold 0 finished
# Training 736 at fold 0 finished
# Training 737 at fold 0 finished
# Training 738 at fold 0 finished
# Training 739 at fold 0 finished
# Training 740 at fold 0 finished
# Training 741 at fold 0 finished
# Training 742 at fold 0 finished
# Training 743 at fold 0 finished
# Training 744 at fold 0 finished
# Training 745 at fold 0 finished
# Training 746 at fold 0 finished
# Training 747 at fold 0 finished
# Training 748 at fold 0 finished
# Training 749 at fold 0 finished
# Training 750 at fold 0 finished
# Training 751 at fold 0 finished
# Training 752 at fold 0 finished
# Training 753 at fold 0 finished
# Training 754 at fold 0 finished
# Training 755 at fold 0 finished
# Training 756 at fold 0 finished
# Training 757 at fold 0 finished
# Training 758 at fold 0 finished
# Training 759 at fold 0 finished
# Training 760 at fold 0 finished
# Training 761 at fold 0 finished
# Training 762 at fold 0 finished
# Training 763 at fold 0 finished
# Training 764 at fold 0 finished
# Training 765 at fold 0 finished
# Training 766 at fold 0 finished
# Training 767 at fold 0 finished
# Training 768 at fold 0 finished
# Training 769 at fold 0 finished
# Training 770 at fold 0 finished
# Training 771 at fold 0 finished
# Training 772 at fold 0 finished
# Training 773 at fold 0 finished
# Training 774 at fold 0 finished
# Training 775 at fold 0 finished
# Training 776 at fold 0 finished
# Training 777 at fold 0 finished
# Training 778 at fold 0 finished
# Training 779 at fold 0 finished
# Training 780 at fold 0 finished
# Training 781 at fold 0 finished
# Training 782 at fold 0 finished
# Training 783 at fold 0 finished
# Training 784 at fold 0 finished
# Training 785 at fold 0 finished
# Training 786 at fold 0 finished
# Training 787 at fold 0 finished
# Training 788 at fold 0 finished
# Training 789 at fold 0 finished
# Training 790 at fold 0 finished
# Training 791 at fold 0 finished
# Training 792 at fold 0 finished
# Training 793 at fold 0 finished
# Training 794 at fold 0 finished
# Training 795 at fold 0 finished
# Training 796 at fold 0 finished
# Training 797 at fold 0 finished
# Training 798 at fold 0 finished
# Training 799 at fold 0 finished
# Training 800 at fold 0 finished
# Training 801 at fold 0 finished
# Training 802 at fold 0 finished
# Training 803 at fold 0 finished
# Training 804 at fold 0 finished
# Training 805 at fold 0 finished
# Training 806 at fold 0 finished
# Training 807 at fold 0 finished
# Training 808 at fold 0 finished
# Training 809 at fold 0 finished
# Training 810 at fold 0 finished
# Training 811 at fold 0 finished
# Training 812 at fold 0 finished
# Training 813 at fold 0 finished
# Training 814 at fold 0 finished
# Training 815 at fold 0 finished
# Training 816 at fold 0 finished
# Training 817 at fold 0 finished
# Training 818 at fold 0 finished
# Training 819 at fold 0 finished
# Training 820 at fold 0 finished
# Training 821 at fold 0 finished
# Training 822 at fold 0 finished
# Training 823 at fold 0 finished
# Training 824 at fold 0 finished
# Training 825 at fold 0 finished
# Training 826 at fold 0 finished
# Training 827 at fold 0 finished
# Training 828 at fold 0 finished
# Training 829 at fold 0 finished
# Training 830 at fold 0 finished
# Training 831 at fold 0 finished
# Training 832 at fold 0 finished
# Training 833 at fold 0 finished
# Training 834 at fold 0 finished
# Training 835 at fold 0 finished
# Training 836 at fold 0 finished
# Training 837 at fold 0 finished
# Training 838 at fold 0 finished
# Training 839 at fold 0 finished
# Training 840 at fold 0 finished
# Training 841 at fold 0 finished
# Training 842 at fold 0 finished
# Training 843 at fold 0 finished
# Training 844 at fold 0 finished
# Training 845 at fold 0 finished
# Training 846 at fold 0 finished
# Training 847 at fold 0 finished
# Training 848 at fold 0 finished
# Training 849 at fold 0 finished
# Training 850 at fold 0 finished
# Training 851 at fold 0 finished
# Training 852 at fold 0 finished
# Training 853 at fold 0 finished
# Training 854 at fold 0 finished
# Training 855 at fold 0 finished
# Training 856 at fold 0 finished
# Training 857 at fold 0 finished
# Training 858 at fold 0 finished
# Training 859 at fold 0 finished
# Training 860 at fold 0 finished
# Training 861 at fold 0 finished
# Training 862 at fold 0 finished
# Training 863 at fold 0 finished
# Training 864 at fold 0 finished
# Training 865 at fold 0 finished
# Training 866 at fold 0 finished
# Training 867 at fold 0 finished
# Training 868 at fold 0 finished
# Training 869 at fold 0 finished
# Training 870 at fold 0 finished
# Training 871 at fold 0 finished
# Training 872 at fold 0 finished
# Training 873 at fold 0 finished
# Training 874 at fold 0 finished
# Training 875 at fold 0 finished
# Training 876 at fold 0 finished
# Training 877 at fold 0 finished
# Training 878 at fold 0 finished
# Training 879 at fold 0 finished
# Training 880 at fold 0 finished
# Training 881 at fold 0 finished
# Training 882 at fold 0 finished
# Training 883 at fold 0 finished
# Training 884 at fold 0 finished
# Training 885 at fold 0 finished
# Training 886 at fold 0 finished
# Training 887 at fold 0 finished
# Training 888 at fold 0 finished
# Training 889 at fold 0 finished
# Training 890 at fold 0 finished
# Training 891 at fold 0 finished
# Training 892 at fold 0 finished
# Training 893 at fold 0 finished
# Training 894 at fold 0 finished
# Training 895 at fold 0 finished
# Training 896 at fold 0 finished
# Training 897 at fold 0 finished
# Training 898 at fold 0 finished
# Training 899 at fold 0 finished
# Training 900 at fold 0 finished
# Training 901 at fold 0 finished
# Training 902 at fold 0 finished
# Training 903 at fold 0 finished
# Training 904 at fold 0 finished
# Training 905 at fold 0 finished
# Training 906 at fold 0 finished
# Training 907 at fold 0 finished
# Training 908 at fold 0 finished
# Training 909 at fold 0 finished
# Training 910 at fold 0 finished
# Training 911 at fold 0 finished
# Training 912 at fold 0 finished
# Training 913 at fold 0 finished
# Training 914 at fold 0 finished
# Training 915 at fold 0 finished
# Training 916 at fold 0 finished
# Training 917 at fold 0 finished
# Training 918 at fold 0 finished
# Training 919 at fold 0 finished
# Training 920 at fold 0 finished
# Training 921 at fold 0 finished
# Training 922 at fold 0 finished
# Training 923 at fold 0 finished
# Training 924 at fold 0 finished
# Training 925 at fold 0 finished
# Training 926 at fold 0 finished
# Training 927 at fold 0 finished
# Training 928 at fold 0 finished
# Training 929 at fold 0 finished
# Training 930 at fold 0 finished
# Training 931 at fold 0 finished
# Training 932 at fold 0 finished
# Training 933 at fold 0 finished
# Training 934 at fold 0 finished
# Training 935 at fold 0 finished
# Training 936 at fold 0 finished
# Training 937 at fold 0 finished
# Training 938 at fold 0 finished
# Training 939 at fold 0 finished
# Training 940 at fold 0 finished
# Training 941 at fold 0 finished
# Training 942 at fold 0 finished
# Training 943 at fold 0 finished
# Training 944 at fold 0 finished
# Training 945 at fold 0 finished
# Training 946 at fold 0 finished
# Training 947 at fold 0 finished
# Training 948 at fold 0 finished
# Training 949 at fold 0 finished
# Training 950 at fold 0 finished
# Training 951 at fold 0 finished
# Training 952 at fold 0 finished
# Training 953 at fold 0 finished
# Training 954 at fold 0 finished
# Training 955 at fold 0 finished
# Training 956 at fold 0 finished
# Training 957 at fold 0 finished
# Training 958 at fold 0 finished
# Training 959 at fold 0 finished
# Training 960 at fold 0 finished
# Training 961 at fold 0 finished
# Training 962 at fold 0 finished
# Training 963 at fold 0 finished
# Training 964 at fold 0 finished
# Training 965 at fold 0 finished
# Training 966 at fold 0 finished
# Training 967 at fold 0 finished
# Training 968 at fold 0 finished
# Training 969 at fold 0 finished
# Training 970 at fold 0 finished
# Training 971 at fold 0 finished
# Training 972 at fold 0 finished
# Training 973 at fold 0 finished
# Training 974 at fold 0 finished
# Training 975 at fold 0 finished
# Training 976 at fold 0 finished
# Training 977 at fold 0 finished
# Training 978 at fold 0 finished
# Training 979 at fold 0 finished
# Training 980 at fold 0 finished
# Training 981 at fold 0 finished
# Training 982 at fold 0 finished
# Training 983 at fold 0 finished
# Training 984 at fold 0 finished
# Training 985 at fold 0 finished
# Training 986 at fold 0 finished
# Training 987 at fold 0 finished
# Training 988 at fold 0 finished
# Training 989 at fold 0 finished
# Training 990 at fold 0 finished
# Training 991 at fold 0 finished
# Training 992 at fold 0 finished
# Training 993 at fold 0 finished
# Training 994 at fold 0 finished
# Training 995 at fold 0 finished
# Training 996 at fold 0 finished
# Training 997 at fold 0 finished
# Training 998 at fold 0 finished
# Training 999 at fold 0 finished
# Training 1000 at fold 0 finished
# Training 1001 at fold 0 finished
# Training 1002 at fold 0 finished
# Training 1003 at fold 0 finished
# Training 1004 at fold 0 finished
# Training 1005 at fold 0 finished
# Training 1006 at fold 0 finished
# Training 1007 at fold 0 finished
# Training 1008 at fold 0 finished
# Training 1009 at fold 0 finished
# Training 1010 at fold 0 finished
# Training 1011 at fold 0 finished
# Training 1012 at fold 0 finished
# Training 1013 at fold 0 finished
# Training 1014 at fold 0 finished
# Training 1015 at fold 0 finished
# Training 1016 at fold 0 finished
# Training 1017 at fold 0 finished
# Training 1018 at fold 0 finished
# Training 1019 at fold 0 finished
# Training 1020 at fold 0 finished
# Training 1021 at fold 0 finished
# Training 1022 at fold 0 finished
# Training 1023 at fold 0 finished
# Training 1024 at fold 0 finished
# Training 1025 at fold 0 finished
# Training 1026 at fold 0 finished
# Training 1027 at fold 0 finished
# Training 1028 at fold 0 finished
# Training 1029 at fold 0 finished
# Training 1030 at fold 0 finished
# Training 1031 at fold 0 finished
# Training 1032 at fold 0 finished
# Training 1033 at fold 0 finished
# Training 1034 at fold 0 finished
# Training 1035 at fold 0 finished
# Training 1036 at fold 0 finished
# Training 1037 at fold 0 finished
# Training 1038 at fold 0 finished
# Training 1039 at fold 0 finished
# Training 1040 at fold 0 finished
# Training 1041 at fold 0 finished
# Training 1042 at fold 0 finished
# Training 1043 at fold 0 finished
# Training 1044 at fold 0 finished
# Training 1045 at fold 0 finished
# Training 1046 at fold 0 finished
# Training 1047 at fold 0 finished
# Training 1048 at fold 0 finished
# Training 1049 at fold 0 finished
# Training 1050 at fold 0 finished
# Training 1051 at fold 0 finished
# Training 1052 at fold 0 finished
# Training 1053 at fold 0 finished
# Training 1054 at fold 0 finished
# Training 1055 at fold 0 finished
# Training 1056 at fold 0 finished
# Training 1057 at fold 0 finished
# Training 1058 at fold 0 finished
# Training 1059 at fold 0 finished
# Training 1060 at fold 0 finished
# Training 1061 at fold 0 finished
# Training 1062 at fold 0 finished
# Training 1063 at fold 0 finished
# Training 1064 at fold 0 finished
# Training 1065 at fold 0 finished
# Training 1066 at fold 0 finished
# Training 1067 at fold 0 finished
# Training 1068 at fold 0 finished
# Training 1069 at fold 0 finished
# Training 1070 at fold 0 finished
# Training 1071 at fold 0 finished
# Training 1072 at fold 0 finished
# Training 1073 at fold 0 finished
# Training 1074 at fold 0 finished
# Training 1075 at fold 0 finished
# Training 1076 at fold 0 finished
# Training 1077 at fold 0 finished
# Training 1078 at fold 0 finished
# Training 1079 at fold 0 finished
# Training 1080 at fold 0 finished
# Training 1081 at fold 0 finished
# Training 1082 at fold 0 finished
# Training 1083 at fold 0 finished
# Training 1084 at fold 0 finished
# Training 1085 at fold 0 finished
# Training 1086 at fold 0 finished
# Training 1087 at fold 0 finished
# Training 1088 at fold 0 finished
# Training 1089 at fold 0 finished
# Training 1090 at fold 0 finished
# Training 1091 at fold 0 finished
# Training 1092 at fold 0 finished
# Training 1093 at fold 0 finished
# Training 1094 at fold 0 finished
# Training 1095 at fold 0 finished
# Training 1096 at fold 0 finished
# Training 1097 at fold 0 finished
# Training 1098 at fold 0 finished
# Training 1099 at fold 0 finished
# Training 1100 at fold 0 finished
# Training 1101 at fold 0 finished
# Training 1102 at fold 0 finished
# Training 1103 at fold 0 finished
# Training 1104 at fold 0 finished
# Training 1105 at fold 0 finished
# Training 1106 at fold 0 finished
# Training 1107 at fold 0 finished
# Training 1108 at fold 0 finished
# Training 1109 at fold 0 finished
# Training 1110 at fold 0 finished
# Training 1111 at fold 0 finished
# Training 1112 at fold 0 finished
# Training 1113 at fold 0 finished
# Training 1114 at fold 0 finished
# Training 1115 at fold 0 finished
# Training 1116 at fold 0 finished
# Training 1117 at fold 0 finished
# Training 1118 at fold 0 finished
# Training 1119 at fold 0 finished
# Training 1120 at fold 0 finished
# Training 1121 at fold 0 finished
# Training 1122 at fold 0 finished
# Training 1123 at fold 0 finished
# Training 1124 at fold 0 finished
# Training 1125 at fold 0 finished
# Training 1126 at fold 0 finished
# Training 1127 at fold 0 finished
# Training 1128 at fold 0 finished
# Training 1129 at fold 0 finished
# Training 1130 at fold 0 finished
# Training 1131 at fold 0 finished
# Training 1132 at fold 0 finished
# Training 1133 at fold 0 finished
# Training 1134 at fold 0 finished
# Training 1135 at fold 0 finished
# Training 1136 at fold 0 finished
# Training 1137 at fold 0 finished
# Training 1138 at fold 0 finished
# Training 1139 at fold 0 finished
# Training 1140 at fold 0 finished
# Training 1141 at fold 0 finished
# Training 1142 at fold 0 finished
# Training 1143 at fold 0 finished
# Training 1144 at fold 0 finished
# Training 1145 at fold 0 finished
# Training 1146 at fold 0 finished
# Training 1147 at fold 0 finished
# Training 1148 at fold 0 finished
# Training 1149 at fold 0 finished
# Training 1150 at fold 0 finished
# Training 1151 at fold 0 finished
# Training 1152 at fold 0 finished
# Training 1153 at fold 0 finished
# Training 1154 at fold 0 finished
# Training 1155 at fold 0 finished
# Training 1156 at fold 0 finished
# Training 1157 at fold 0 finished
# Training 1158 at fold 0 finished
# Training 1159 at fold 0 finished
# Training 1160 at fold 0 finished
# Training 1161 at fold 0 finished
# Training 1162 at fold 0 finished
# Training 1163 at fold 0 finished
# Training 1164 at fold 0 finished
# Training 1165 at fold 0 finished
# Training 1166 at fold 0 finished
# Training 1167 at fold 0 finished
# Training 1168 at fold 0 finished
# Training 1169 at fold 0 finished
# Training 1170 at fold 0 finished
# Training 1171 at fold 0 finished
# Training 1172 at fold 0 finished
# Training 1173 at fold 0 finished
# Training 1174 at fold 0 finished
# Training 1175 at fold 0 finished
# Training 1176 at fold 0 finished
# Training 1177 at fold 0 finished
# Training 1178 at fold 0 finished
# Training 1179 at fold 0 finished
# Training 1180 at fold 0 finished
# Training 1181 at fold 0 finished
# Training 1182 at fold 0 finished
# Training 1183 at fold 0 finished
# Training 1184 at fold 0 finished
# Training 1185 at fold 0 finished
# Training 1186 at fold 0 finished
# Training 1187 at fold 0 finished
# Training 1188 at fold 0 finished
# Training 1189 at fold 0 finished
# Training 1190 at fold 0 finished
# Training 1191 at fold 0 finished
# Training 1192 at fold 0 finished
# Training 1193 at fold 0 finished
# Training 1194 at fold 0 finished
# Training 1195 at fold 0 finished
# Training 1196 at fold 0 finished
# Training 1197 at fold 0 finished
# Training 1198 at fold 0 finished
# Training 1199 at fold 0 finished
# Training 1200 at fold 0 finished
# Training 1201 at fold 0 finished
# Training 1202 at fold 0 finished
# Training 1203 at fold 0 finished
# Training 1204 at fold 0 finished
# Training 1205 at fold 0 finished
# Training 1206 at fold 0 finished
# Training 1207 at fold 0 finished
# Training 1208 at fold 0 finished
# Training 1209 at fold 0 finished
# Training 1210 at fold 0 finished
# Training 1211 at fold 0 finished
# Training 1212 at fold 0 finished
# Training 1213 at fold 0 finished
# Training 1214 at fold 0 finished
# Training 1215 at fold 0 finished
# Training 1216 at fold 0 finished
# Training 1217 at fold 0 finished
# Training 1218 at fold 0 finished
# Training 1219 at fold 0 finished
# Training 1220 at fold 0 finished
# Training 1221 at fold 0 finished
# Training 1222 at fold 0 finished
# Training 1223 at fold 0 finished
# Training 1224 at fold 0 finished
# Training 1225 at fold 0 finished
# Training 1226 at fold 0 finished
# Training 1227 at fold 0 finished
# Training 1228 at fold 0 finished
# Training 1229 at fold 0 finished
# Training 1230 at fold 0 finished
# Training 1231 at fold 0 finished
# Training 1232 at fold 0 finished
# Training 1233 at fold 0 finished
# Training 1234 at fold 0 finished
# Training 1235 at fold 0 finished
# Training 1236 at fold 0 finished
# Training 1237 at fold 0 finished
# Training 1238 at fold 0 finished
# Training 1239 at fold 0 finished
# Training 1240 at fold 0 finished
# Training 1241 at fold 0 finished
# Training 1242 at fold 0 finished
# Training 1243 at fold 0 finished
# Training 1244 at fold 0 finished
# Training 1245 at fold 0 finished
# Training 1246 at fold 0 finished
# Training 1247 at fold 0 finished
# Training 1248 at fold 0 finished
# Training 1249 at fold 0 finished
# Training 1250 at fold 0 finished
# Training 1251 at fold 0 finished
# Training 1252 at fold 0 finished
# Training 1253 at fold 0 finished
# Training 1254 at fold 0 finished
# Training 1255 at fold 0 finished
# Training 1256 at fold 0 finished
# Training 1257 at fold 0 finished
# Training 1258 at fold 0 finished
# Training 1259 at fold 0 finished
# Training 1260 at fold 0 finished
# Training 1261 at fold 0 finished
# Training 1262 at fold 0 finished
# Training 1263 at fold 0 finished
# Training 1264 at fold 0 finished
# Training 1265 at fold 0 finished
# Training 1266 at fold 0 finished
# Training 1267 at fold 0 finished
# Training 1268 at fold 0 finished
# Training 1269 at fold 0 finished
# Training 1270 at fold 0 finished
# Training 1271 at fold 0 finished
# Training 1272 at fold 0 finished
# Training 1273 at fold 0 finished
# Training 1274 at fold 0 finished
# Training 1275 at fold 0 finished
# Training 1276 at fold 0 finished
# Training 1277 at fold 0 finished
# Training 1278 at fold 0 finished
# Training 1279 at fold 0 finished
# Training 1280 at fold 0 finished
# Training 1281 at fold 0 finished
# Training 1282 at fold 0 finished
# Training 1283 at fold 0 finished
# Training 1284 at fold 0 finished
# Training 1285 at fold 0 finished
# Training 1286 at fold 0 finished
# Training 1287 at fold 0 finished
# Training 1288 at fold 0 finished
# Training 1289 at fold 0 finished
# Training 1290 at fold 0 finished
# Training 1291 at fold 0 finished
# Training 1292 at fold 0 finished
# Training 1293 at fold 0 finished
# Training 1294 at fold 0 finished
# Training 1295 at fold 0 finished
# Training 1296 at fold 0 finished
# Training 1297 at fold 0 finished
# Training 1298 at fold 0 finished
# Training 1299 at fold 0 finished
# Training 1300 at fold 0 finished
# Training 1301 at fold 0 finished
# Training 1302 at fold 0 finished
# Training 1303 at fold 0 finished
# Training 1304 at fold 0 finished
# Training 1305 at fold 0 finished
# Training 1306 at fold 0 finished
# Training 1307 at fold 0 finished
# Training 1308 at fold 0 finished
# Training 1309 at fold 0 finished
# Training 1310 at fold 0 finished
# Training 1311 at fold 0 finished
# Training 1312 at fold 0 finished
# Training 1313 at fold 0 finished
# Training 1314 at fold 0 finished
# Training 1315 at fold 0 finished
# Training 1316 at fold 0 finished
# Training 1317 at fold 0 finished
# Training 1318 at fold 0 finished
# Training 1319 at fold 0 finished
# Training 1320 at fold 0 finished
# Training 1321 at fold 0 finished
# Training 1322 at fold 0 finished
# Training 1323 at fold 0 finished
# Training 1324 at fold 0 finished
# Training 1325 at fold 0 finished
# Training 1326 at fold 0 finished
# Training 1327 at fold 0 finished
# Training 1328 at fold 0 finished
# Training 1329 at fold 0 finished
# Training 1330 at fold 0 finished
# Training 1331 at fold 0 finished
# Training 1332 at fold 0 finished
# Training 1333 at fold 0 finished
# Training 1334 at fold 0 finished
# Training 1335 at fold 0 finished
# Training 1336 at fold 0 finished
# Training 1337 at fold 0 finished
# Training 1338 at fold 0 finished
# Training 1339 at fold 0 finished
# Training 1340 at fold 0 finished
# Training 1341 at fold 0 finished
# Training 1342 at fold 0 finished
# Training 1343 at fold 0 finished
# Training 1344 at fold 0 finished
# Training 1345 at fold 0 finished
# Training 1346 at fold 0 finished
# Training 1347 at fold 0 finished
# Training 1348 at fold 0 finished
# Training 1349 at fold 0 finished
# Training 1350 at fold 0 finished
# Training 1351 at fold 0 finished
# Training 1352 at fold 0 finished
# Training 1353 at fold 0 finished
# Training 1354 at fold 0 finished
# Training 1355 at fold 0 finished
# Training 1356 at fold 0 finished
# Training 1357 at fold 0 finished
# Training 1358 at fold 0 finished
# Training 1359 at fold 0 finished
# Training 1360 at fold 0 finished
# Training 1361 at fold 0 finished
# Training 1362 at fold 0 finished
# Training 1363 at fold 0 finished
# Training 1364 at fold 0 finished
# Training 1365 at fold 0 finished
# Training 1366 at fold 0 finished
# Training 1367 at fold 0 finished
# Training 1368 at fold 0 finished
# Training 1369 at fold 0 finished
# Training 1370 at fold 0 finished
# Training 1371 at fold 0 finished
# Training 1372 at fold 0 finished
# Training 1373 at fold 0 finished
# Training 1374 at fold 0 finished
# Training 1375 at fold 0 finished
# Training 1376 at fold 0 finished
# Training 1377 at fold 0 finished
# Training 1378 at fold 0 finished
# Training 1379 at fold 0 finished
# Training 1380 at fold 0 finished
# Training 1381 at fold 0 finished
# Training 1382 at fold 0 finished
# Training 1383 at fold 0 finished
# Training 1384 at fold 0 finished
# Training 1385 at fold 0 finished
# Training 1386 at fold 0 finished
# Training 1387 at fold 0 finished
# Training 1388 at fold 0 finished
# Training 1389 at fold 0 finished
# Training 1390 at fold 0 finished
# Training 1391 at fold 0 finished
# Training 1392 at fold 0 finished
# Training 1393 at fold 0 finished
# Training 1394 at fold 0 finished
# Training 1395 at fold 0 finished
# Training 1396 at fold 0 finished
# Training 1397 at fold 0 finished
# Training 1398 at fold 0 finished
# Training 1399 at fold 0 finished
# Training 1400 at fold 0 finished
# Training 1401 at fold 0 finished
# Training 1402 at fold 0 finished
# Training 1403 at fold 0 finished
# Training 1404 at fold 0 finished
# Training 1405 at fold 0 finished
# Training 1406 at fold 0 finished
# Training 1407 at fold 0 finished
# Training 1408 at fold 0 finished
# Training 1409 at fold 0 finished
# Training 1410 at fold 0 finished
# Training 1411 at fold 0 finished
# Training 1412 at fold 0 finished
# Training 1413 at fold 0 finished
# Training 1414 at fold 0 finished
# Training 1415 at fold 0 finished
# Training 1416 at fold 0 finished
# Training 1417 at fold 0 finished
# Training 1418 at fold 0 finished
# Training 1419 at fold 0 finished
# Training 1420 at fold 0 finished
# Training 1421 at fold 0 finished
# Training 1422 at fold 0 finished
# Training 1423 at fold 0 finished
# Training 1424 at fold 0 finished
# Training 1425 at fold 0 finished
# Training 1426 at fold 0 finished
# Training 1427 at fold 0 finished
# Training 1428 at fold 0 finished
# Training 1429 at fold 0 finished
# Training 1430 at fold 0 finished
# Training 1431 at fold 0 finished
# Training 1432 at fold 0 finished
# Training 1433 at fold 0 finished
# Training 1434 at fold 0 finished
# Training 1435 at fold 0 finished
# Training 1436 at fold 0 finished
# Training 1437 at fold 0 finished
# Training 1438 at fold 0 finished
# Training 1439 at fold 0 finished
# Training 1440 at fold 0 finished
# Training 1441 at fold 0 finished
# Training 1442 at fold 0 finished
# Training 1443 at fold 0 finished
# Training 1444 at fold 0 finished
# Training 1445 at fold 0 finished
# Training 1446 at fold 0 finished
# Training 1447 at fold 0 finished
# Training 1448 at fold 0 finished
# Training 1449 at fold 0 finished
# Training 1450 at fold 0 finished
# Training 1451 at fold 0 finished
# Training 1452 at fold 0 finished
# Training 1453 at fold 0 finished
# Training 1454 at fold 0 finished
# Training 1455 at fold 0 finished
# Training 1456 at fold 0 finished
# Training 1457 at fold 0 finished
# Training 1458 at fold 0 finished
# Training 1459 at fold 0 finished
# Training 1460 at fold 0 finished
# Training 1461 at fold 0 finished
# Training 1462 at fold 0 finished
# Training 1463 at fold 0 finished
# Training 1464 at fold 0 finished
# Training 1465 at fold 0 finished
# Training 1466 at fold 0 finished
# Training 1467 at fold 0 finished
# Training 1468 at fold 0 finished
# Training 1469 at fold 0 finished
# Training 1470 at fold 0 finished
# Training 1471 at fold 0 finished
# Training 1472 at fold 0 finished
# Training 1473 at fold 0 finished
# Training 1474 at fold 0 finished
# Training 1475 at fold 0 finished
# Training 1476 at fold 0 finished
# Training 1477 at fold 0 finished
# Training 1478 at fold 0 finished
# Training 1479 at fold 0 finished
# Training 1480 at fold 0 finished
# Training 1481 at fold 0 finished
# Training 1482 at fold 0 finished
# Training 1483 at fold 0 finished
# Training 1484 at fold 0 finished
# Training 1485 at fold 0 finished
# Training 1486 at fold 0 finished
# Training 1487 at fold 0 finished
# Training 1488 at fold 0 finished
# ...
# Training 1239 at fold 9 finished
# Training 1240 at fold 9 finished
# Training 1241 at fold 9 finished
# Training 1242 at fold 9 finished
# Training 1243 at fold 9 finished
# Training 1244 at fold 9 finished
# Training 1245 at fold 9 finished
# Training 1246 at fold 9 finished
# Training 1247 at fold 9 finished
# Training 1248 at fold 9 finished
# Training 1249 at fold 9 finished
# Training 1250 at fold 9 finished
# Training 1251 at fold 9 finished
# Training 1252 at fold 9 finished
# Training 1253 at fold 9 finished
# Training 1254 at fold 9 finished
# Training 1255 at fold 9 finished
# Training 1256 at fold 9 finished
# Training 1257 at fold 9 finished
# Training 1258 at fold 9 finished
# Training 1259 at fold 9 finished
# Training 1260 at fold 9 finished
# Training 1261 at fold 9 finished
# Training 1262 at fold 9 finished
# Training 1263 at fold 9 finished
# Training 1264 at fold 9 finished
# Training 1265 at fold 9 finished
# Training 1266 at fold 9 finished
# Training 1267 at fold 9 finished
# Training 1268 at fold 9 finished
# Training 1269 at fold 9 finished
# Training 1270 at fold 9 finished
# Training 1271 at fold 9 finished
# Training 1272 at fold 9 finished
# Training 1273 at fold 9 finished
# Training 1274 at fold 9 finished
# Training 1275 at fold 9 finished
# Training 1276 at fold 9 finished
# Training 1277 at fold 9 finished
# Training 1278 at fold 9 finished
# Training 1279 at fold 9 finished
# Training 1280 at fold 9 finished
# Training 1281 at fold 9 finished
# Training 1282 at fold 9 finished
# Training 1283 at fold 9 finished
# Training 1284 at fold 9 finished
# Training 1285 at fold 9 finished
# Training 1286 at fold 9 finished
# Training 1287 at fold 9 finished
# Training 1288 at fold 9 finished
# Training 1289 at fold 9 finished
# Training 1290 at fold 9 finished
# Training 1291 at fold 9 finished
# Training 1292 at fold 9 finished
# Training 1293 at fold 9 finished
# Training 1294 at fold 9 finished
# Training 1295 at fold 9 finished
# Training 1296 at fold 9 finished
# Training 1297 at fold 9 finished
# Training 1298 at fold 9 finished
# Training 1299 at fold 9 finished
# Training 1300 at fold 9 finished
# Training 1301 at fold 9 finished
# Training 1302 at fold 9 finished
# Training 1303 at fold 9 finished
# Training 1304 at fold 9 finished
# Training 1305 at fold 9 finished
# Training 1306 at fold 9 finished
# Training 1307 at fold 9 finished
# Training 1308 at fold 9 finished
# Training 1309 at fold 9 finished
# Training 1310 at fold 9 finished
# Training 1311 at fold 9 finished
# Training 1312 at fold 9 finished
# Training 1313 at fold 9 finished
# Training 1314 at fold 9 finished
# Training 1315 at fold 9 finished
# Training 1316 at fold 9 finished
# Training 1317 at fold 9 finished
# Training 1318 at fold 9 finished
# Training 1319 at fold 9 finished
# Training 1320 at fold 9 finished
# Training 1321 at fold 9 finished
# Training 1322 at fold 9 finished
# Training 1323 at fold 9 finished
# Training 1324 at fold 9 finished
# Training 1325 at fold 9 finished
# Training 1326 at fold 9 finished
# Training 1327 at fold 9 finished
# Training 1328 at fold 9 finished
# Training 1329 at fold 9 finished
# Training 1330 at fold 9 finished
# Training 1331 at fold 9 finished
# Training 1332 at fold 9 finished
# Training 1333 at fold 9 finished
# Training 1334 at fold 9 finished
# Training 1335 at fold 9 finished
# Training 1336 at fold 9 finished
# Training 1337 at fold 9 finished
# Training 1338 at fold 9 finished
# Training 1339 at fold 9 finished
# Training 1340 at fold 9 finished
# Training 1341 at fold 9 finished
# Training 1342 at fold 9 finished
# Training 1343 at fold 9 finished
# Training 1344 at fold 9 finished
# Training 1345 at fold 9 finished
# Training 1346 at fold 9 finished
# Training 1347 at fold 9 finished
# Training 1348 at fold 9 finished
# Training 1349 at fold 9 finished
# Training 1350 at fold 9 finished
# Training 1351 at fold 9 finished
# Training 1352 at fold 9 finished
# Training 1353 at fold 9 finished
# Training 1354 at fold 9 finished
# Training 1355 at fold 9 finished
# Training 1356 at fold 9 finished
# Training 1357 at fold 9 finished
# Training 1358 at fold 9 finished
# Training 1359 at fold 9 finished
# Training 1360 at fold 9 finished
# Training 1361 at fold 9 finished
# Training 1362 at fold 9 finished
# Training 1363 at fold 9 finished
# Training 1364 at fold 9 finished
# Training 1365 at fold 9 finished
# Training 1366 at fold 9 finished
# Training 1367 at fold 9 finished
# Training 1368 at fold 9 finished
# Training 1369 at fold 9 finished
# Training 1370 at fold 9 finished
# Training 1371 at fold 9 finished
# Training 1372 at fold 9 finished
# Training 1373 at fold 9 finished
# Training 1374 at fold 9 finished
# Training 1375 at fold 9 finished
# Training 1376 at fold 9 finished
# Training 1377 at fold 9 finished
# Training 1378 at fold 9 finished
# Training 1379 at fold 9 finished
# Training 1380 at fold 9 finished
# Training 1381 at fold 9 finished
# Training 1382 at fold 9 finished
# Training 1383 at fold 9 finished
# Training 1384 at fold 9 finished
# Training 1385 at fold 9 finished
# Training 1386 at fold 9 finished
# Training 1387 at fold 9 finished
# Training 1388 at fold 9 finished
# Training 1389 at fold 9 finished
# Training 1390 at fold 9 finished
# Training 1391 at fold 9 finished
# Training 1392 at fold 9 finished
# Training 1393 at fold 9 finished
# Training 1394 at fold 9 finished
# Training 1395 at fold 9 finished
# Training 1396 at fold 9 finished
# Training 1397 at fold 9 finished
# Training 1398 at fold 9 finished
# Training 1399 at fold 9 finished
# Training 1400 at fold 9 finished
# Training 1401 at fold 9 finished
# Training 1402 at fold 9 finished
# Training 1403 at fold 9 finished
# Training 1404 at fold 9 finished
# Training 1405 at fold 9 finished
# Training 1406 at fold 9 finished
# Training 1407 at fold 9 finished
# Training 1408 at fold 9 finished
# Training 1409 at fold 9 finished
# Training 1410 at fold 9 finished
# Training 1411 at fold 9 finished
# Training 1412 at fold 9 finished
# Training 1413 at fold 9 finished
# Training 1414 at fold 9 finished
# Training 1415 at fold 9 finished
# Training 1416 at fold 9 finished
# Training 1417 at fold 9 finished
# Training 1418 at fold 9 finished
# Training 1419 at fold 9 finished
# Training 1420 at fold 9 finished
# Training 1421 at fold 9 finished
# Training 1422 at fold 9 finished
# Training 1423 at fold 9 finished
# Training 1424 at fold 9 finished
# Training 1425 at fold 9 finished
# Training 1426 at fold 9 finished
# Training 1427 at fold 9 finished
# Training 1428 at fold 9 finished
# Training 1429 at fold 9 finished
# Training 1430 at fold 9 finished
# Training 1431 at fold 9 finished
# Training 1432 at fold 9 finished
# Training 1433 at fold 9 finished
# Training 1434 at fold 9 finished
# Training 1435 at fold 9 finished
# Training 1436 at fold 9 finished
# Training 1437 at fold 9 finished
# Training 1438 at fold 9 finished
# Training 1439 at fold 9 finished
# Training 1440 at fold 9 finished
# Training 1441 at fold 9 finished
# Training 1442 at fold 9 finished
# Training 1443 at fold 9 finished
# Training 1444 at fold 9 finished
# Training 1445 at fold 9 finished
# Training 1446 at fold 9 finished
# Training 1447 at fold 9 finished
# Training 1448 at fold 9 finished
# Training 1449 at fold 9 finished
# Training 1450 at fold 9 finished
# Training 1451 at fold 9 finished
# Training 1452 at fold 9 finished
# Training 1453 at fold 9 finished
# Training 1454 at fold 9 finished
# Training 1455 at fold 9 finished
# Training 1456 at fold 9 finished
# Training 1457 at fold 9 finished
# Training 1458 at fold 9 finished
# Training 1459 at fold 9 finished
# Training 1460 at fold 9 finished
# Training 1461 at fold 9 finished
# Training 1462 at fold 9 finished
# Training 1463 at fold 9 finished
# Training 1464 at fold 9 finished
# Training 1465 at fold 9 finished
# Training 1466 at fold 9 finished
# Training 1467 at fold 9 finished
# Training 1468 at fold 9 finished
# Training 1469 at fold 9 finished
# Training 1470 at fold 9 finished
# Training 1471 at fold 9 finished
# Training 1472 at fold 9 finished
# Training 1473 at fold 9 finished
# Training 1474 at fold 9 finished
# Training 1475 at fold 9 finished
# Training 1476 at fold 9 finished
# Training 1477 at fold 9 finished
# Training 1478 at fold 9 finished
# Training 1479 at fold 9 finished
# Training 1480 at fold 9 finished
# Training 1481 at fold 9 finished
# Training 1482 at fold 9 finished
# Training 1483 at fold 9 finished
# Training 1484 at fold 9 finished
# Training 1485 at fold 9 finished
# Training 1486 at fold 9 finished
# Training 1487 at fold 9 finished
# Training 1488 at fold 9 finished
# Training 1489 at fold 9 finished
# Training 1490 at fold 9 finished
# Training 1491 at fold 9 finished
# Training 1492 at fold 9 finished
# Training 1493 at fold 9 finished
# Training 1494 at fold 9 finished
# Training 1495 at fold 9 finished
# Training 1496 at fold 9 finished
# Training 1497 at fold 9 finished
# Training 1498 at fold 9 finished
# Training 1499 at fold 9 finished
# Training 1500 at fold 9 finished
# Training 1501 at fold 9 finished
# Training 1502 at fold 9 finished
# Training 1503 at fold 9 finished
# Training 1504 at fold 9 finished
# Training 1505 at fold 9 finished
# Training 1506 at fold 9 finished
# Training 1507 at fold 9 finished
# Training 1508 at fold 9 finished
# Training 1509 at fold 9 finished
# Training 1510 at fold 9 finished
# Training 1511 at fold 9 finished
# Training 1512 at fold 9 finished
# Training 1513 at fold 9 finished
# Training 1514 at fold 9 finished
# Training 1515 at fold 9 finished
# Training 1516 at fold 9 finished
# Training 1517 at fold 9 finished
# Training 1518 at fold 9 finished
# Training 1519 at fold 9 finished
# Training 1520 at fold 9 finished
# Training 1521 at fold 9 finished
# Training 1522 at fold 9 finished
# Training 1523 at fold 9 finished
# Training 1524 at fold 9 finished
# Training 1525 at fold 9 finished
# Training 1526 at fold 9 finished
# Training 1527 at fold 9 finished
# Training 1528 at fold 9 finished
# Training 1529 at fold 9 finished
# Training 1530 at fold 9 finished
# Training 1531 at fold 9 finished
# Training 1532 at fold 9 finished
# Training 1533 at fold 9 finished
# Training 1534 at fold 9 finished
# Training 1535 at fold 9 finished
# Training 1536 at fold 9 finished
# Training 1537 at fold 9 finished
# Training 1538 at fold 9 finished
# Training 1539 at fold 9 finished
# Training 1540 at fold 9 finished
# Training 1541 at fold 9 finished
# Training 1542 at fold 9 finished
# Training 1543 at fold 9 finished
# Training 1544 at fold 9 finished
# Training 1545 at fold 9 finished
# Training 1546 at fold 9 finished
# Training 1547 at fold 9 finished
# Training 1548 at fold 9 finished
# Validation 1 at fold 9 finished
# Validation 2 at fold 9 finished
# Validation 3 at fold 9 finished
# Validation 4 at fold 9 finished
# Validation 5 at fold 9 finished
# Validation 6 at fold 9 finished
# Validation 7 at fold 9 finished
# Validation 8 at fold 9 finished
# Validation 9 at fold 9 finished
# Validation 10 at fold 9 finished
# Validation 11 at fold 9 finished
# Validation 12 at fold 9 finished
# Validation 13 at fold 9 finished
# Validation 14 at fold 9 finished
# Validation 15 at fold 9 finished
# Validation 16 at fold 9 finished
# Validation 17 at fold 9 finished
# Validation 18 at fold 9 finished
# Validation 19 at fold 9 finished
# Validation 20 at fold 9 finished
# Validation 21 at fold 9 finished
# Validation 22 at fold 9 finished
# Validation 23 at fold 9 finished
# Validation 24 at fold 9 finished
# Validation 25 at fold 9 finished
# Validation 26 at fold 9 finished
# Validation 27 at fold 9 finished
# Validation 28 at fold 9 finished
# Validation 29 at fold 9 finished
# Validation 30 at fold 9 finished
# Validation 31 at fold 9 finished
# Validation 32 at fold 9 finished
# Validation 33 at fold 9 finished
# Validation 34 at fold 9 finished
# Validation 35 at fold 9 finished
# Validation 36 at fold 9 finished
# Validation 37 at fold 9 finished
# Validation 38 at fold 9 finished
# Validation 39 at fold 9 finished
# Validation 40 at fold 9 finished
# Validation 41 at fold 9 finished
# Validation 42 at fold 9 finished
# Validation 43 at fold 9 finished
# Validation 44 at fold 9 finished
# Validation 45 at fold 9 finished
# Validation 46 at fold 9 finished
# Validation 47 at fold 9 finished
# Validation 48 at fold 9 finished
# Validation 49 at fold 9 finished
# Validation 50 at fold 9 finished
# Validation 51 at fold 9 finished
# Validation 52 at fold 9 finished
# Validation 53 at fold 9 finished
# Validation 54 at fold 9 finished
# Validation 55 at fold 9 finished
# Validation 56 at fold 9 finished
# Validation 57 at fold 9 finished
# Validation 58 at fold 9 finished
# Validation 59 at fold 9 finished
# Validation 60 at fold 9 finished
# Validation 61 at fold 9 finished
# Validation 62 at fold 9 finished
# Validation 63 at fold 9 finished
# Validation 64 at fold 9 finished
# Validation 65 at fold 9 finished
# Validation 66 at fold 9 finished
# Validation 67 at fold 9 finished
# Validation 68 at fold 9 finished
# Validation 69 at fold 9 finished
# Validation 70 at fold 9 finished
# Validation 71 at fold 9 finished
# Validation 72 at fold 9 finished
# Validation 73 at fold 9 finished
# Validation 74 at fold 9 finished
# Validation 75 at fold 9 finished
# Validation 76 at fold 9 finished
# Validation 77 at fold 9 finished
# Validation 78 at fold 9 finished
# Validation 79 at fold 9 finished
# Validation 80 at fold 9 finished
# Validation 81 at fold 9 finished
# Validation 82 at fold 9 finished
# Validation 83 at fold 9 finished
# Validation 84 at fold 9 finished
# Validation 85 at fold 9 finished
# Validation 86 at fold 9 finished
# Validation 87 at fold 9 finished
# Validation 88 at fold 9 finished
# Validation 89 at fold 9 finished
# Validation 90 at fold 9 finished
# Validation 91 at fold 9 finished
# Validation 92 at fold 9 finished
# Validation 93 at fold 9 finished
# Validation 94 at fold 9 finished
# Validation 95 at fold 9 finished
# Validation 96 at fold 9 finished
# Validation 97 at fold 9 finished
# Validation 98 at fold 9 finished
# Validation 99 at fold 9 finished
# Validation 100 at fold 9 finished
# Validation 101 at fold 9 finished
# Validation 102 at fold 9 finished
# Validation 103 at fold 9 finished
# Validation 104 at fold 9 finished
# Validation 105 at fold 9 finished
# Validation 106 at fold 9 finished
# Validation 107 at fold 9 finished
# Validation 108 at fold 9 finished
# Validation 109 at fold 9 finished
# Validation 110 at fold 9 finished
# Validation 111 at fold 9 finished
# Validation 112 at fold 9 finished
# Validation 113 at fold 9 finished
# Validation 114 at fold 9 finished
# Validation 115 at fold 9 finished
# Validation 116 at fold 9 finished
# Validation 117 at fold 9 finished
# Validation 118 at fold 9 finished
# Validation 119 at fold 9 finished
# Validation 120 at fold 9 finished
# Validation 121 at fold 9 finished
# Validation 122 at fold 9 finished
# Validation 123 at fold 9 finished
# Validation 124 at fold 9 finished
# Validation 125 at fold 9 finished
# Validation 126 at fold 9 finished
# Validation 127 at fold 9 finished
# Validation 128 at fold 9 finished
# Validation 129 at fold 9 finished
# Validation 130 at fold 9 finished
# Validation 131 at fold 9 finished
# Validation 132 at fold 9 finished
# Validation 133 at fold 9 finished
# Validation 134 at fold 9 finished
# Validation 135 at fold 9 finished
# Validation 136 at fold 9 finished
# Validation 137 at fold 9 finished
# Validation 138 at fold 9 finished
# Validation 139 at fold 9 finished
# Validation 140 at fold 9 finished
# Validation 141 at fold 9 finished
# Validation 142 at fold 9 finished
# Validation 143 at fold 9 finished
# Validation 144 at fold 9 finished
# Validation 145 at fold 9 finished
# Validation 146 at fold 9 finished
# Validation 147 at fold 9 finished
# Validation 148 at fold 9 finished
# Validation 149 at fold 9 finished
# Validation 150 at fold 9 finished
# Validation 151 at fold 9 finished
# Validation 152 at fold 9 finished
# Validation 153 at fold 9 finished
# Validation 154 at fold 9 finished
# Validation 155 at fold 9 finished
# Validation 156 at fold 9 finished
# Validation 157 at fold 9 finished
# Validation 158 at fold 9 finished
# Validation 159 at fold 9 finished
# Validation 160 at fold 9 finished
# Validation 161 at fold 9 finished
# Validation 162 at fold 9 finished
# Validation 163 at fold 9 finished
# Validation 164 at fold 9 finished
# Validation 165 at fold 9 finished
# Validation 166 at fold 9 finished
# Validation 167 at fold 9 finished
# Validation 168 at fold 9 finished
# Validation 169 at fold 9 finished
# Validation 170 at fold 9 finished
# Validation 171 at fold 9 finished
# Validation 172 at fold 9 finished

# %%
for i in range(cfg_train['fold']):
    plot_fold_from_master(folds_dict, fold_idx=i)
